# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('Quikr_car.csv')
car.head()
# Out:
#    Unnamed: 0                                          Name     Label  \
# 0           0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1           1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2           2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3           3                          Hyundai Venue - 2019  PLATINUM
# 4           4                             Honda Jazz - 2017  PLATINUM
#
#     Location       Price   Kms_driven Fuel_type       Owner  Year  Company
# 0  Bangalore   ₹3,80,000  35,056 kms     Petrol         NaN  2015     Ford
# 1  Bangalore   ₹4,65,000  44,000 kms     Petrol         NaN  2016   Maruti
# 2  Bangalore  ₹13,50,000  42,917 kms     Petrol         NaN  2018  Hyundai
# 3    Chennai  ₹10,19,699  16,112 kms    Petrol    2nd Owner  2019  Hyundai
# 4       Pune   ₹7,13,499  30,988 kms    Petrol    2nd Owner  2017    Honda

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1032 non-null   int64
#  1   Name        1032 non-null   object
#  2   Label       1032 non-null   object
#  3   Location    1030 non-null   object
#  4   Price       1032 non-null   object
#  5   Kms_driven  1032 non-null   object
#  6   Fuel_type   1032 non-null   object
#  7   Owner       740 non-null    object
#  8   Year        1032 non-null   int64
#  9   Company     1032 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 80.8+ KB

# %%
car.shape
# Out:
# (1032, 10)

# %%
car['Name'].unique
# Out:
# <bound method Series.unique of 0            Ford Figo Duratec Petrol EXI 1.2 - 2015
# 1             Maruti Suzuki Wagon R VXI BS IV - 2016
# 2       Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018
# 3                               Hyundai Venue - 2019
# 4                                  Honda Jazz - 2017
#                             ...
# 1027                    Hyundai i10 Magna 1.2 - 2014
# 1028           Maruti Suzuki Alto K10 LXi CNG - 2014
# 1029          Jeep Compass Limited 2.0 Diesel - 2017
# 1030          Jeep Compass Limited 2.0 Diesel - 2017
# 1031          Jeep Compass Limited 2.0 Diesel - 2017
# Name: Name, Length: 1032, dtype: object>

# %%
car['Label'].unique
# Out:
# <bound method Series.unique of 0       PLATINUM
# 1       PLATINUM
# 2       PLATINUM
# 3       PLATINUM
# 4       PLATINUM
#           ...
# 1027        GOLD
# 1028        GOLD
# 1029        GOLD
# 1030        GOLD
# 1031        GOLD
# Name: Label, Length: 1032, dtype: object>

# %%
car['Location'].unique
# Out:
# <bound method Series.unique of 0        Bangalore
# 1        Bangalore
# 2        Bangalore
# 3          Chennai
# 4             Pune
#            ...
# 1027     Bangalore
# 1028     Bangalore
# 1029    Mahasamund
# 1030      Bilaspur
# 1031     Jagdalpur
# Name: Location, Length: 1032, dtype: object>

# %%
car['Price'].unique
# Out:
# <bound method Series.unique of 0        ₹3,80,000
# 1        ₹4,65,000
# 2       ₹13,50,000
# 3       ₹10,19,699
# 4        ₹7,13,499
#            ...
# 1027     ₹2,29,000
# 1028     ₹2,75,000
# 1029    ₹17,50,000
# 1030    ₹17,50,000
# 1031    ₹17,50,000
# Name: Price, Length: 1032, dtype: object>

# %%
car['Kms_driven'].unique
# Out:
# <bound method Series.unique of 0       35,056 kms
# 1       44,000 kms
# 2       42,917 kms
# 3       16,112 kms
# 4       30,988 kms
#            ...
# 1027    65,000 kms
# 1028    60,000 kms
# 1029    31,000 kms
# 1030    31,000 kms
# 1031    31,000 kms
# Name: Kms_driven, Length: 1032, dtype: object>

# %%
car['Fuel_type'].unique
# Out:
# <bound method Series.unique of 0         Petrol
# 1         Petrol
# 2         Petrol
# 3        Petrol
# 4        Petrol
#           ...
# 1027     Petrol
# 1028      Petrol
# 1029     Diesel
# 1030     Diesel
# 1031     Diesel
# Name: Fuel_type, Length: 1032, dtype: object>

# %%
car['Owner'].unique
# Out:
# <bound method Series.unique of 0              NaN
# 1              NaN
# 2              NaN
# 3        2nd Owner
# 4        2nd Owner
#            ...
# 1027     1st Owner
# 1028           NaN
# 1029     1st Owner
# 1030     1st Owner
# 1031     1st Owner
# Name: Owner, Length: 1032, dtype: object>

# %%
car['Year'].unique
# Out:
# <bound method Series.unique of 0       2015
# 1       2016
# 2       2018
# 3       2019
# 4       2017
#         ...
# 1027    2014
# 1028    2014
# 1029    2017
# 1030    2017
# 1031    2017
# Name: Year, Length: 1032, dtype: int64>

# %%
car['Company'].unique
# Out:
# <bound method Series.unique of 0          Ford
# 1        Maruti
# 2       Hyundai
# 3       Hyundai
# 4         Honda
#          ...
# 1027    Hyundai
# 1028     Maruti
# 1029       Jeep
# 1030       Jeep
# 1031       Jeep
# Name: Company, Length: 1032, dtype: object>

# %% [markdown]
# #quality
# price object to integer
# kms driven has kms with integers
# kms driven object to int
# owner has nan values
# keep first 2 words of name

# %%
#Data Cleaning 
backup=car.copy()

# %%
car[car['Year'].astype(str).str.isnumeric()]
# Out:
#       Unnamed: 0                                          Name     Label  \
# 0              0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1              1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2              2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3              3                          Hyundai Venue - 2019  PLATINUM
# 4              4                             Honda Jazz - 2017  PLATINUM
# ...          ...                                           ...       ...
# 1027        1027                  Hyundai i10 Magna 1.2 - 2014      GOLD
# 1028        1028         Maruti Suzuki Alto K10 LXi CNG - 2014      GOLD
# 1029        1029        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1030        1030        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1031        1031        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
#
#         Location       Price   Kms_driven Fuel_type       Owner  Year  Company
# ...

# %%
car['Year']=car['Year'].astype(int)

# %%
car=car[car['Price']!="Ask For Price"]

# %%
car['Price']=car['Price'].astype(str).str.replace('[₹,]','',regex=True).astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1026 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1026 non-null   int64
#  1   Name        1026 non-null   object
#  2   Label       1026 non-null   object
#  3   Location    1024 non-null   object
#  4   Price       1026 non-null   int64
#  5   Kms_driven  1026 non-null   object
#  6   Fuel_type   1026 non-null   object
#  7   Owner       738 non-null    object
#  8   Year        1026 non-null   int64
#  9   Company     1026 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 88.2+ KB

# %%
car['Kms_driven']=car['Kms_driven'].str.split(' ').str.get(0).str.replace(',','')

# %%
car[car['Kms_driven'].str.isnumeric()]
# Out:
#       Unnamed: 0                                          Name     Label  \
# 0              0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1              1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2              2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3              3                          Hyundai Venue - 2019  PLATINUM
# 4              4                             Honda Jazz - 2017  PLATINUM
# ...          ...                                           ...       ...
# 1027        1027                  Hyundai i10 Magna 1.2 - 2014      GOLD
# 1028        1028         Maruti Suzuki Alto K10 LXi CNG - 2014      GOLD
# 1029        1029        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1030        1030        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1031        1031        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
#
#         Location    Price Kms_driven Fuel_type       Owner  Year  Company
# ...

# %%
car['Kms_driven']=car['Kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1026 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1026 non-null   int64
#  1   Name        1026 non-null   object
#  2   Label       1026 non-null   object
#  3   Location    1024 non-null   object
#  4   Price       1026 non-null   int64
#  5   Kms_driven  1026 non-null   int64
#  6   Fuel_type   1026 non-null   object
#  7   Owner       738 non-null    object
#  8   Year        1026 non-null   int64
#  9   Company     1026 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 88.2+ KB

# %%
car=car[~car['Fuel_type'].isna()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1026 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1026 non-null   int64
#  1   Name        1026 non-null   object
#  2   Label       1026 non-null   object
#  3   Location    1024 non-null   object
#  4   Price       1026 non-null   int64
#  5   Kms_driven  1026 non-null   int64
#  6   Fuel_type   1026 non-null   object
#  7   Owner       738 non-null    object
#  8   Year        1026 non-null   int64
#  9   Company     1026 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 88.2+ KB

# %%
car=car[~car['Owner'].isna()]

# %%
car=car[~car['Location'].isna()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737 entries, 3 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  737 non-null    int64
#  1   Name        737 non-null    object
#  2   Label       737 non-null    object
#  3   Location    737 non-null    object
#  4   Price       737 non-null    int64
#  5   Kms_driven  737 non-null    int64
#  6   Fuel_type   737 non-null    object
#  7   Owner       737 non-null    object
#  8   Year        737 non-null    int64
#  9   Company     737 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 63.3+ KB

# %%
car['Name']=car['Name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car
# Out:
#       Unnamed: 0                  Name     Label    Location    Price  \
# 3              3       Hyundai Venue -  PLATINUM     Chennai  1019699
# 4              4          Honda Jazz -  PLATINUM        Pune   713499
# 5              5         Hyundai i20 -  PLATINUM        Pune   391099
# 6              6   Maruti Suzuki Swift  PLATINUM        Pune   474299
# 7              7  Toyota Corolla Altis  PLATINUM        Pune  1252999
# ...          ...                   ...       ...         ...      ...
# 1023        1023      Ford Figo Aspire  PLATINUM        Pune   481399
# 1027        1027     Hyundai i10 Magna      GOLD   Bangalore   229000
# 1029        1029  Jeep Compass Limited      GOLD  Mahasamund  1750000
# 1030        1030  Jeep Compass Limited      GOLD    Bilaspur  1750000
# 1031        1031  Jeep Compass Limited      GOLD   Jagdalpur  1750000
#
#       Kms_driven Fuel_type       Owner  Year  Company
# 3          16112   Petrol    2nd Owner  2019  Hyundai
# ...

# %%
car.describe()
# Out:
#         Unnamed: 0         Price     Kms_driven         Year
# count   737.000000  7.370000e+02     737.000000   737.000000
# mean    518.613297  6.798567e+05   42865.037992  2016.645862
# std     301.379250  3.803285e+05   28514.239221     2.299152
# min       3.000000  7.300000e+04     700.000000  2001.000000
# 25%     250.000000  4.470990e+05   22667.000000  2015.000000
# 50%     531.000000  5.725990e+05   36277.000000  2017.000000
# 75%     781.000000  7.788880e+05   58492.000000  2018.000000
# max    1031.000000  3.300000e+06  210000.000000  2022.000000

# %%
car[car['Price']>3e6]
# Out:
#      Unnamed: 0                    Name Label Location    Price  Kms_driven  \
# 930         930  Porsche Cayenne Select  GOLD   Mumbai  3300000       38000
#
#       Fuel_type       Owner  Year  Company
# 930   Electric    1st Owner  2011  Porsche

# %%
car=car.reset_index(drop=True)

# %%
car
# Out:
#                      Name     Label    Location    Price  Kms_driven  \
# 0         Hyundai Venue -  PLATINUM     Chennai  1019699       16112
# 1            Honda Jazz -  PLATINUM        Pune   713499       30988
# 2           Hyundai i20 -  PLATINUM        Pune   391099       69163
# 3     Maruti Suzuki Swift  PLATINUM        Pune   474299       42859
# 4    Toyota Corolla Altis  PLATINUM        Pune  1252999       34919
# ..                    ...       ...         ...      ...         ...
# 732      Ford Figo Aspire  PLATINUM        Pune   481399       29632
# 733     Hyundai i10 Magna      GOLD   Bangalore   229000       65000
# 734  Jeep Compass Limited      GOLD  Mahasamund  1750000       31000
# 735  Jeep Compass Limited      GOLD    Bilaspur  1750000       31000
# 736  Jeep Compass Limited      GOLD   Jagdalpur  1750000       31000
#
#     Fuel_type       Owner  Year  Company
# 0     Petrol    2nd Owner  2019  Hyundai
# 1     Petrol    2nd Owner  2017    Honda
# ...

# %%
car.to_csv('Cars.csv')

# %% [markdown]
# MODEL

# %%
x=car.drop(columns='Price')
y=car['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(x[['Name','Company','Fuel_type',]])
# Out:
# OneHotEncoder()

# %%
ct = make_column_transformer(
    (OneHotEncoder(handle_unknown='ignore'), ['Name', 'Company', 'Fuel_type', 'Label', 'Location', 'Owner']),
    remainder='passthrough'
)
lr=LinearRegression()
pipe=make_pipeline(ct,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Name', 'Company',
#                                                    'Fuel_type', 'Label',
#                                                    'Location', 'Owner'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6678540858612638

# %%
scores=[]
for i in range(1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(ct,lr)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# np.int64(852)

# %%
scores[np.argmax(scores)]
# Out:
# 0.8557249459612366

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(ct,lr)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.8557249459612366

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Toyota Corolla Altis','Platinum','Pune','34919','Petrol','1st Owner','2017','Toyota']], columns=['Name','Label','Location','Kms_driven','Fuel_type','Owner','Year','Company']))
# Out:
# array([1187711.87288664])
